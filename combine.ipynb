# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import os
os.environ["HOME"] = os.path.expanduser("~")
import modulus
import torch

print("Modulus OK")
print("CUDA:", torch.cuda.is_available())
# Out:
# Modulus OK
# CUDA: False

# %%
from modulus.sym.eq.pdes.navier_stokes import NavierStokes

ns = NavierStokes(
    nu=0.01,
    rho=1.0,
    dim=2,
    time=False
)

print(ns.equations)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from modulus.sym.eq.pdes.navier_stokes import NavierStokes
#       3 ns = NavierStokes(
#       4     nu=0.01,
#       5     rho=1.0,
#       6     dim=2,
#       7     time=False
#       8 )
#      10 print(ns.equations)
#
# ModuleNotFoundError: No module named 'modulus.sym'
